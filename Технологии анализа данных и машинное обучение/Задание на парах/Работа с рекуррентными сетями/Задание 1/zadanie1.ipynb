# %% [markdown]
# Эксперимент 1: Изменение длины последовательности (seq_length = 3)

# %%
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.utils import to_categorical

numpy.random.seed(7)
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
char_to_int = dict((c, i) for i, c in enumerate(alphabet))
int_to_char = dict((i, c) for i, c in enumerate(alphabet))

seq_length = 3
dataX = []
dataY = []

for i in range(0, len(alphabet) - seq_length, 1):
    seq_in = alphabet[i : i + seq_length]
    seq_out = alphabet[i + seq_length]
    dataX.append([char_to_int[char] for char in seq_in])
    dataY.append(char_to_int[seq_out])
    print(seq_in, "->", seq_out)

X = numpy.reshape(dataX, (len(dataX), seq_length, 1))
X = X / float(len(alphabet))
y = to_categorical(dataY)

model = Sequential()
model.add(LSTM(32, input_shape=(X.shape[1], X.shape[2])))
model.add(Dense(y.shape[1], activation="softmax"))
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.fit(X, y, epochs=50, batch_size=1, verbose=2)

scores = model.evaluate(X, y, verbose=0)

print("Model Accuracy: %.2f%%" % (scores[1] * 100))
for pattern in dataX:
    x = numpy.reshape(pattern, (1, len(pattern), 1))
    x = x / float(len(alphabet))
    prediction = model.predict(x, verbose=0)
    index = numpy.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[value] for value in pattern]
    print(seq_in, "->", result)
# Out:
# ABC -> D
# BCD -> E
# CDE -> F
# DEF -> G
# EFG -> H
# FGH -> I
# GHI -> J
# HIJ -> K
# IJK -> L
# JKL -> M
# KLM -> N
# LMN -> O
# MNO -> P
# NOP -> Q
# OPQ -> R
# PQR -> S
# QRS -> T
# RST -> U
# STU -> V
# TUV -> W
# UVW -> X
# VWX -> Y
# WXY -> Z
# Epoch 1/50
# 23/23 - 1s - 56ms/step - accuracy: 0.0000e+00 - loss: 3.2782
# Epoch 2/50
# 23/23 - 0s - 3ms/step - accuracy: 0.0870 - loss: 3.2631
# Epoch 3/50
# 23/23 - 0s - 3ms/step - accuracy: 0.0435 - loss: 3.2556
# Epoch 4/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 3.2481
# Epoch 5/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 3.2398
# Epoch 6/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 3.2314
# Epoch 7/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 3.2232
# Epoch 8/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 3.2148
# Epoch 9/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 3.2025
# Epoch 10/50
# 23/23 - 0s - 4ms/step - accuracy: 0.0000e+00 - loss: 3.1908
# Epoch 11/50
# 23/23 - 0s - 3ms/step - accuracy: 0.0435 - loss: 3.1770
# Epoch 12/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 3.1608
# Epoch 13/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 3.1472
# Epoch 14/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 3.1280
# Epoch 15/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 3.1110
# Epoch 16/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 3.0922
# Epoch 17/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 3.0767
# Epoch 18/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 3.0601
# Epoch 19/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 3.0475
# Epoch 20/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 3.0330
# Epoch 21/50
# 23/23 - 0s - 4ms/step - accuracy: 0.0435 - loss: 3.0166
# Epoch 22/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0870 - loss: 3.0009
# Epoch 23/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0870 - loss: 2.9853
# Epoch 24/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0870 - loss: 2.9642
# Epoch 25/50
# 23/23 - 0s - 3ms/step - accuracy: 0.0870 - loss: 2.9453
# Epoch 26/50
# 23/23 - 0s - 3ms/step - accuracy: 0.0870 - loss: 2.9211
# Epoch 27/50
# 23/23 - 0s - 3ms/step - accuracy: 0.0870 - loss: 2.9033
# Epoch 28/50
# 23/23 - 0s - 3ms/step - accuracy: 0.0870 - loss: 2.8767
# Epoch 29/50
# 23/23 - 0s - 3ms/step - accuracy: 0.0870 - loss: 2.8518
# Epoch 30/50
# 23/23 - 0s - 3ms/step - accuracy: 0.0435 - loss: 2.8306
# Epoch 31/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0870 - loss: 2.8032
# Epoch 32/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0870 - loss: 2.7681
# Epoch 33/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 2.7394
# Epoch 34/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0870 - loss: 2.7149
# Epoch 35/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0870 - loss: 2.6786
# Epoch 36/50
# 23/23 - 0s - 3ms/step - accuracy: 0.0435 - loss: 2.6533
# Epoch 37/50
# 23/23 - 0s - 3ms/step - accuracy: 0.0435 - loss: 2.6258
# Epoch 38/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 2.5951
# Epoch 39/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 2.5704
# Epoch 40/50
# 23/23 - 0s - 3ms/step - accuracy: 0.0435 - loss: 2.5459
# Epoch 41/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 2.5215
# Epoch 42/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0870 - loss: 2.5001
# Epoch 43/50
# 23/23 - 0s - 3ms/step - accuracy: 0.0870 - loss: 2.4725
# Epoch 44/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0435 - loss: 2.4517
# Epoch 45/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0870 - loss: 2.4218
# Epoch 46/50
# 23/23 - 0s - 2ms/step - accuracy: 0.0870 - loss: 2.4040
# Epoch 47/50
# 23/23 - 0s - 2ms/step - accuracy: 0.1304 - loss: 2.3749
# Epoch 48/50
# 23/23 - 0s - 2ms/step - accuracy: 0.1304 - loss: 2.3515
# Epoch 49/50
# 23/23 - 0s - 2ms/step - accuracy: 0.1304 - loss: 2.3274
# Epoch 50/50
# 23/23 - 0s - 2ms/step - accuracy: 0.2609 - loss: 2.3022
# Model Accuracy: 26.09%
# ['A', 'B', 'C'] -> D
# ['B', 'C', 'D'] -> D
# ['C', 'D', 'E'] -> D
# ['D', 'E', 'F'] -> D
# ['E', 'F', 'G'] -> D
# ['F', 'G', 'H'] -> F
# ['G', 'H', 'I'] -> F
# ['H', 'I', 'J'] -> K
# ['I', 'J', 'K'] -> K
# ['J', 'K', 'L'] -> M
# ['K', 'L', 'M'] -> P
# ['L', 'M', 'N'] -> P
# ['M', 'N', 'O'] -> P
# ['N', 'O', 'P'] -> R
# ['O', 'P', 'Q'] -> R
# ['P', 'Q', 'R'] -> W
# ['Q', 'R', 'S'] -> W
# ['R', 'S', 'T'] -> Z
# ['S', 'T', 'U'] -> Z
# ['T', 'U', 'V'] -> Y
# ['U', 'V', 'W'] -> Y
# ['V', 'W', 'X'] -> Y
# ['W', 'X', 'Y'] -> Y

# %% [markdown]
# Эксперимент 2: Увеличение количества LSTM-блоков

# %%
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.utils import to_categorical

numpy.random.seed(7)
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
char_to_int = dict((c, i) for i, c in enumerate(alphabet))
int_to_char = dict((i, c) for i, c in enumerate(alphabet))

# Параметры последовательности
seq_length = 1
dataX = []
dataY = []

# Подготовка данных
for i in range(0, len(alphabet) - seq_length, 1):
    seq_in = alphabet[i : i + seq_length]
    seq_out = alphabet[i + seq_length]
    dataX.append([char_to_int[char] for char in seq_in])
    dataY.append(char_to_int[seq_out])
    print(seq_in, "->", seq_out)

# Формирование данных для обучения
X = numpy.reshape(dataX, (len(dataX), seq_length, 1))
X = X / float(len(alphabet))
y = to_categorical(dataY)

# Построение модели с двумя LSTM-блоками
model = Sequential()
model.add(LSTM(32, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(LSTM(32))
model.add(Dense(y.shape[1], activation="softmax"))
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Обучение модели
model.fit(X, y, epochs=50, batch_size=1, verbose=2)

# Оценка модели
scores = model.evaluate(X, y, verbose=0)
print("Model Accuracy: %.2f%%" % (scores[1] * 100))

# Предсказания на обучающих данных
for pattern in dataX:
    x = numpy.reshape(pattern, (1, len(pattern), 1))
    x = x / float(len(alphabet))
    prediction = model.predict(x, verbose=0)
    index = numpy.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[value] for value in pattern]
    print(seq_in, "->", result)
# Out:
# A -> B
# B -> C
# C -> D
# D -> E
# E -> F
# F -> G
# G -> H
# H -> I
# I -> J
# J -> K
# K -> L
# L -> M
# M -> N
# N -> O
# O -> P
# P -> Q
# Q -> R
# R -> S
# S -> T
# T -> U
# U -> V
# V -> W
# W -> X
# X -> Y
# Y -> Z
# Epoch 1/50
# 25/25 - 2s - 86ms/step - accuracy: 0.0000e+00 - loss: 3.2638
# Epoch 2/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0400 - loss: 3.2583
# Epoch 3/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0400 - loss: 3.2569
# Epoch 4/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0400 - loss: 3.2554
# Epoch 5/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0400 - loss: 3.2537
# Epoch 6/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0000e+00 - loss: 3.2518
# Epoch 7/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0400 - loss: 3.2493
# Epoch 8/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0400 - loss: 3.2462
# Epoch 9/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0400 - loss: 3.2422
# Epoch 10/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0400 - loss: 3.2362
# Epoch 11/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0400 - loss: 3.2269
# Epoch 12/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0400 - loss: 3.2150
# Epoch 13/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0400 - loss: 3.1960
# Epoch 14/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0000e+00 - loss: 3.1766
# Epoch 15/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0400 - loss: 3.1486
# Epoch 16/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0000e+00 - loss: 3.1238
# Epoch 17/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0400 - loss: 3.0978
# Epoch 18/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0400 - loss: 3.0760
# Epoch 19/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0800 - loss: 3.0480
# Epoch 20/50
# 25/25 - 0s - 3ms/step - accuracy: 0.1200 - loss: 3.0227
# Epoch 21/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0800 - loss: 2.9992
# Epoch 22/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0800 - loss: 2.9714
# Epoch 23/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0800 - loss: 2.9460
# Epoch 24/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0800 - loss: 2.9193
# Epoch 25/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0400 - loss: 2.8962
# Epoch 26/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0800 - loss: 2.8725
# Epoch 27/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0400 - loss: 2.8486
# Epoch 28/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0800 - loss: 2.8252
# Epoch 29/50
# 25/25 - 0s - 3ms/step - accuracy: 0.1200 - loss: 2.8049
# Epoch 30/50
# 25/25 - 0s - 4ms/step - accuracy: 0.0800 - loss: 2.7855
# Epoch 31/50
# 25/25 - 0s - 5ms/step - accuracy: 0.0800 - loss: 2.7632
# Epoch 32/50
# 25/25 - 0s - 4ms/step - accuracy: 0.0800 - loss: 2.7459
# Epoch 33/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0800 - loss: 2.7266
# Epoch 34/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0800 - loss: 2.7105
# Epoch 35/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0800 - loss: 2.6924
# Epoch 36/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0800 - loss: 2.6742
# Epoch 37/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0800 - loss: 2.6585
# Epoch 38/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0800 - loss: 2.6439
# Epoch 39/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0800 - loss: 2.6260
# Epoch 40/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0800 - loss: 2.6106
# Epoch 41/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0800 - loss: 2.5994
# Epoch 42/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0800 - loss: 2.5809
# Epoch 43/50
# 25/25 - 0s - 6ms/step - accuracy: 0.0800 - loss: 2.5600
# Epoch 44/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0800 - loss: 2.5425
# Epoch 45/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0400 - loss: 2.5286
# Epoch 46/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0400 - loss: 2.5036
# Epoch 47/50
# 25/25 - 0s - 2ms/step - accuracy: 0.0800 - loss: 2.4874
# Epoch 48/50
# 25/25 - 0s - 3ms/step - accuracy: 0.0800 - loss: 2.4679
# Epoch 49/50
# 25/25 - 0s - 3ms/step - accuracy: 0.1200 - loss: 2.4430
# Epoch 50/50
# 25/25 - 0s - 2ms/step - accuracy: 0.1200 - loss: 2.4239
# Model Accuracy: 16.00%
# ['A'] -> B
# ['B'] -> B
# ['C'] -> B
# ['D'] -> B
# ['E'] -> B
# ['F'] -> B
# ['G'] -> B
# ['H'] -> E
# ['I'] -> I
# ['J'] -> J
# ['K'] -> N
# ['L'] -> N
# ['M'] -> N
# ['N'] -> Q
# ['O'] -> Q
# ['P'] -> Q
# ['Q'] -> Q
# ['R'] -> V
# ['S'] -> Y
# ['T'] -> Z
# ['U'] -> Z
# ['V'] -> Z
# ['W'] -> Z
# ['X'] -> Z
# ['Y'] -> Z
